# %% [markdown]
# # Module 1
# # Importing Necessary Modules
#
#   We import all the modules that we are going to use in this code.
#
#   1) Pandas for handling our .csv file & converting it to a usable DataFrame
#
#   2) Warnings to filter out all the unnecessary warning messages
#
#   3) Matplotlib & Seaborn for showing our visualizations using different available plots
#
#   4) Datetime & Time for Data Cleaning

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import matplotlib as plt
from matplotlib import pyplot
import seaborn as sns


from datetime import datetime
from datetime import date

# %% [markdown]
# # Collecting & Reading Our Dataset
#
# Now we read our .csv file and convert it to a pandas DataFrame and observe its necessary features

# %%
missing_values = ["n/a", "na", "--","NA","N/A",'-']
df = pd.read_csv(r'E:\Rohan\Datasets\SuperMarket Sales\supermarket sales - Copy.csv', na_values = missing_values)

df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69       7.0  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28       5.0   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33       7.0  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22       8.0  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31       7.0  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# As observed above, we have a total of 17 features in our dataset
#
# Let's take a closer look into the properties of each feature

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1003.000000  1007.000000  1001.000000  1003.000000  1000.00000
# mean     55.672173     5.504469    15.394893   322.772265   307.58738
# std      26.486425     2.922411    11.713272   246.012296   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      33.050000     3.000000     5.955000   122.498250   118.49750
# 50%      55.070000     5.000000    12.096000   253.680000   241.76000
# 75%      77.940000     8.000000    22.491000   471.670500   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.001000e+03   1001.000000  1000.00000
# mean              4.761905e+00     15.394893     6.97270
# std               7.522461e-09     11.713272     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# The describe() function returns a set of unique features of each column. We can observe our data through this to get an overview of what we are working on and get a basic understanding.
#
# Let's look at another function that can give us more features for us to observe.

# %%
df.describe(include="all")
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1020   1012    1009          1010    1009                 1007
# unique         1020      4       3             3       4                    6
# top     249-42-3782      A  Yangon        Member  Female  Fashion accessories
# freq              1    349     344           507     504                  180
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# 75%             NaN    NaN     NaN           NaN     NaN                  NaN
# max             NaN    NaN     NaN           NaN     NaN                  NaN
#
# ...

# %% [markdown]
# Here we notice the features for all our columns. We notice that our dataset has a total of 1020 unique values. We also notive that there are alot of missing values as well, as it shows a total of 4 unique Gender values. Hence this dataset has NaNs which has to be filtered.
#
# There are also 3 types of cities that we our supermarkets are located at. We are going to primarily work on these locations.
#
# We notice there are 3 types of payments done, we'll have a look at them later on.

# %% [markdown]
# # Module 2
# # Data Cleaning
#
# It's the process that is done on our dataset so that we can filter/remove unwanted data that is not either in the correct format, has no meaning or even an empty value. This process is done purely to increase the accuracy of our analysis and predictions.
#
# In simple terms it means the cleaning of unstructured data to a much more structured form of data that can be used more efficiently.

# %% [markdown]
# Let's start with the renaming our dataset columns to a much more sophisticated look

# %%
df=df.rename(columns={"cogs":"Cost Of Goods Sold",
                      'gross margin percentage':'Gross Margin Percentage',
                      'gross income':'Gross Income',
                      'Customer type':'Customer Type'})

df.head()
# Out:
#     Invoice ID Branch       City Customer Type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69       7.0  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28       5.0   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33       7.0  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22       8.0  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31       7.0  30.2085  634.3785   2/8/2019
#
#     Time      Payment  Cost Of Goods Sold  Gross Margin Percentage  \
# 0  13:08      Ewallet              522.83                 4.761905
# ...

# %% [markdown]
# We observe that the column names have been changed to a much more approachable manner for understanding

# %% [markdown]
# Let us now inspect on the number of Null values our dataset possesses

# %%
missing_data=df.isnull()
print(missing_data.tail(6))
# Out:
#       Invoice ID  Branch   City  Customer Type  Gender  Product line  \
# 1014       False   False  False          False   False         False
# 1015       False   False  False          False   False         False
# 1016       False   False  False          False   False         False
# 1017       False   False  False          False   False         False
# 1018       False   False  False          False   False         False
# 1019       False   False  False          False    True         False
#
#       Unit price  Quantity  Tax 5%  Total   Date   Time  Payment  \
# 1014       False     False   False  False  False  False    False
# 1015       False     False   False  False  False  False    False
# 1016       False     False   False  False  False  False    False
# 1017       False     False   False  False  False  False    False
# 1018       False     False   False  False  False  False    False
# 1019       False     False   False  False   True  False    False
#
# ...

# %% [markdown]
# Here we observe a dataset called missing_data which has all the values of the features in a Boolean format.
#
# False regards to a value that is not null & True regards to a value that is missing. After printing the last 6 rows of our dataset, we observe a few True values.
#
# Let us make a count of each of these for each column.

# %%
for columns in missing_data.columns.values.tolist():
    print(columns)
    print(missing_data[columns].value_counts())
    print("")
# Out:
# Invoice ID
# False    1020
# Name: Invoice ID, dtype: int64
#
# Branch
# False    1012
# True        8
# Name: Branch, dtype: int64
#
# City
# False    1009
# True       11
# Name: City, dtype: int64
#
# Customer Type
# False    1010
# True       10
# Name: Customer Type, dtype: int64
#
# Gender
# False    1009
# True       11
# Name: Gender, dtype: int64
#
# Product line
# False    1007
# True       13
# Name: Product line, dtype: int64
#
# Unit price
# False    1003
# True       17
# Name: Unit price, dtype: int64
#
# Quantity
# False    1007
# True       13
# Name: Quantity, dtype: int64
#
# Tax 5%
# False    1001
# True       19
# Name: Tax 5%, dtype: int64
#
# Total
# False    1003
# True       17
# Name: Total, dtype: int64
#
# Date
# False    1006
# True       14
# Name: Date, dtype: int64
#
# Time
# False    1005
# True       15
# Name: Time, dtype: int64
#
# Payment
# False    1008
# True       12
# Name: Payment, dtype: int64
#
# Cost Of Goods Sold
# False    1000
# ...

# %% [markdown]
# This code gives us a clear idea about the total null values that are present in each column.
#
# Since there are just a maximum of 20 and our dataset is ranging to 1000, we can drop off these values.

# %%
df.dropna(inplace=True)
df.dropna(how = 'all') #DROP THE OVERALL ROW
# Out:
#        Invoice ID Branch       City Customer Type  Gender  \
# 0     750-67-8428      A     Yangon        Member  Female
# 1     226-31-3081      C  Naypyitaw        Normal  Female
# 2     631-41-3108      A     Yangon        Normal    Male
# 3     123-19-1176      A     Yangon        Member    Male
# 4     373-73-7910      A     Yangon        Normal    Male
# ...           ...    ...        ...           ...     ...
# 1014  233-67-5758      C  Naypyitaw        Normal    Male
# 1015  303-96-2227      B   Mandalay        Normal  Female
# 1016  727-02-1313      A     Yangon        Member    Male
# 1017  347-56-2442      A     Yangon        Normal    Male
# 1018  849-09-3807      A     Yangon        Member  Female
#
#                 Product line  Unit price  Quantity   Tax 5%      Total  \
# 0          Health and beauty       74.69       7.0  26.1415   548.9715
# 1     Electronic accessories       15.28       5.0   3.8200    80.2200
# ...

# %% [markdown]
# Now let's check the total sum of all the null values. It should give us a value of zero.

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# We got zero. Now let us see the total values for each feature.

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  Cost Of Goods Sold  \
# count  1000.000000  1000.000000  1000.000000  1000.000000          1000.00000
# mean     55.672130     5.510000    15.379369   322.966749           307.58738
# std      26.494628     2.923431    11.708825   245.885335           234.17651
# min      10.080000     1.000000     0.508500    10.678500            10.17000
# 25%      32.875000     3.000000     5.924875   124.422375           118.49750
# 50%      55.230000     5.000000    12.088000   253.848000           241.76000
# 75%      77.935000     8.000000    22.445250   471.350250           448.90500
# max      99.960000    10.000000    49.650000  1042.650000           993.00000
#
#        Gross Margin Percentage  Gross Income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.220360e-14     11.708825     1.71858
# ...

# %% [markdown]
# Now each column has 1000 values which can be used for analysis.

# %% [markdown]
# Let us observe all the unique values in our dataset, for each column.

# %%
#CHECKING UNIQUE VALUES
print("Unique values in Branch: {0}".format(len(df['Branch'].unique().tolist())))
print("Unique values in City: {0}".format(len(df['City'].unique().tolist())))
print("Unique values in Customer Type: {0}".format(len(df['Customer Type'].unique().tolist())))
print("Unique values in Gender: {0}".format(len(df['Gender'].unique().tolist())))
print("Unique values in Product Line: {0}".format(len(df['Product line'].unique().tolist())))
print("Unique values in Payment: {0}".format(len(df['Payment'].unique().tolist())))
# Out:
# Unique values in Branch: 3
# Unique values in City: 3
# Unique values in Customer Type: 2
# Unique values in Gender: 2
# Unique values in Product Line: 6
# Unique values in Payment: 3

# %% [markdown]
# # Module 3
# # Data Formatting
#
# Let us observe the types of each column in our dataset.

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer Type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                   float64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# Cost Of Goods Sold         float64
# Gross Margin Percentage    float64
# Gross Income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# Not all the columns are of the specified/needed type. Let's change these.

# %%
#DATA FORMATTING
df[['Quantity']]=df[['Quantity']].astype("int")
df['Date']=df['Date']+df['Time']
df['Date'] =  pd.to_datetime(df['Date'], format='%m/%d/%Y%H:%M')
df['Day'] = (df['Date']).dt.day
df['Month'] = (df['Date']).dt.month
df['Year'] = (df['Date']).dt.year
df['Hours'] = (df['Date']).dt.hour
df['Minutes'] = (df['Date']).dt.minute


#CHANGING THE TYPES OF COLUMNS 
df[['Day']]=df[['Day']].astype("int")
df[['Month']]=df[['Month']].astype("int")
df[['Year']]=df[['Year']].astype("int")
df[['Hours']]=df[['Hours']].astype("int")
df[['Minutes']]=df[['Minutes']].astype("int")

df=df.rename(columns={"Date":"DateTime"})

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer Type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int32
# Tax 5%                            float64
# Total                             float64
# DateTime                   datetime64[ns]
# Time                               object
# Payment                            object
# Cost Of Goods Sold                float64
# Gross Margin Percentage           float64
# Gross Income                      float64
# Rating                            float64
# Day                                 int32
# Month                               int32
# Year                                int32
# Hours                               int32
# Minutes                             int32
# dtype: object

# %% [markdown]
# Now the data looks more approachable.

# %% [markdown]
# Let us also round up the floating values for easier accessibility and calculation.

# %%
df=df.round({'Unit price': 2, 'Tax 5%': 2,'Total':2, 'cogs':2, 'gross margin percentage':2,
          'gross income':2,'rating':1})
df.head()
# Out:
#     Invoice ID Branch       City Customer Type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity  Tax 5%   Total  ...  \
# 0       Health and beauty       74.69         7   26.14  548.97  ...
# 1  Electronic accessories       15.28         5    3.82   80.22  ...
# 2      Home and lifestyle       46.33         7   16.22  340.53  ...
# 3       Health and beauty       58.22         8   23.29  489.05  ...
# 4       Sports and travel       86.31         7   30.21  634.38  ...
#
#        Payment Cost Of Goods Sold Gross Margin Percentage  Gross Income  \
# 0      Ewallet             522.83                4.761905       26.1415
# ...

# %% [markdown]
# # Data Normalization
#
# It refers to rescaling by the minimum and range of the vector, to make all the elements lie between 0 and 1 (scaling down) thus bringing all the values of numeric columns in the dataset to a common scale. Here, the only factor that can be rescaled is the rating factor. However for us, the format it already is in (1-10) is useful for us and we won't use data normalization for this project.

# %% [markdown]
# # Binning
#
# For a clear usage of the price & rating, we will perform binning on both these features.
#
# For Price, we are going to create three categories --- LOW, MEDIUM, HIGH
#
# For Rating, we are going to create five categories --- VERY LOW, LOW, MEDIUM, HIGH, VERY HIGH
#
# Let's perform this and create seperate columns & add them to our working dataframe

# %%
#BINNING
bins = np.linspace(min(df["Total"]), max(df["Total"]), 4)


bin_names=['Low','Medium','High']
df['Price Category'] = pd.cut(df['Total'], bins, labels=bin_names, include_lowest=True)
#print(df['Price Category','Total'].head())


bins1 = np.linspace(min(df["Rating"]), max(df["Rating"]), 6)

bin_names1=['Very Low Rating','Low Rating','Medium Rating','High Rating','Very High Rating']
df['Rating Category'] = pd.cut(df['Rating'], bins1, labels=bin_names1, include_lowest=True)
#print(df['Rating Category','Rating'].head())


print(list(bins))

print(list(bins1))

df.head()
# Out:
# [10.68, 354.67, 698.66, 1042.65]
# [4.0, 5.2, 6.4, 7.6, 8.8, 10.0]
#     Invoice ID Branch       City Customer Type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity  Tax 5%   Total  ...  \
# 0       Health and beauty       74.69         7   26.14  548.97  ...
# 1  Electronic accessories       15.28         5    3.82   80.22  ...
# 2      Home and lifestyle       46.33         7   16.22  340.53  ...
# 3       Health and beauty       58.22         8   23.29  489.05  ...
# 4       Sports and travel       86.31         7   30.21  634.38  ...
#
#   Gross Margin Percentage Gross Income Rating  Day  Month  Year  Hours  \
# 0                4.761905      26.1415    9.1    5      1  2019     13
# ...

# %% [markdown]
# As observed in the list, The first list is the breakdown of binning of the price category for labelling.
#
# The second list is the breakdown for the rating category.

# %% [markdown]
# Let us look at some insights of our data

# %%
#GROUPING OF DATA
print(df.groupby('Product line'))

# %% [markdown]
# Here, the dataset is seperated by groupby function, based on the Product line. Hence all our data will be segregated on the basis of the different types of the products.

# %% [markdown]
# # Module 4
# # Visualizations
#
# Now, we will start looking at the different visualizations we can extract from our structured dataset.
#
# Let's look at count value for our price category & see which products are sold more.

# %%
# %matplotlib inline
def show_price_category():
    plt.pyplot.hist(df["Price Category"],color="#0504aa",alpha=0.50,bins='auto',rwidth=10)
    plt.pyplot.xlabel("Price Category")
    plt.pyplot.ylabel("Count")
    plt.pyplot.title("PRICE CATEGORY VS COUNT")
    plt.pyplot.show()

show_price_category()

# %% [markdown]
# Low category products are sold significantly more than the other categories.
#
# Let's see the price ratings that customers give for the sold products.

# %%
sns.set(font_scale=0.8)
sns.set_palette("RdBu")
sns.catplot(x="Rating Category",data=df,kind="count",order=bin_names1)
plt.pyplot.show()

# %% [markdown]
# A mixed reaction, products seem to be getting a rating less than the average rating. Let us further inspect these rating based on the different locations where the store is situated.

# %%
sns.set(font_scale=0.9)
d=sns.countplot(x="Branch",hue="Rating Category",palette="hsv",order=["A","B","C"],data=df)

# %% [markdown]
# Now we can see that Branch B has more lower ratings than the other Branches. Branch A & C have comparable higher ratings.
#
#
# Let us now look at the how the product prices fare out.

# %%
#COUNTING PRICE VARIATION
s=plt.pyplot.hist(df["Total"],histtype='barstacked',facecolor="skyblue",alpha=1.0,orientation='vertical')
s=plt.pyplot.xlabel("Total Price")
s=plt.pyplot.ylabel("Count")
s=plt.pyplot.title("TOTAL PRICE VS COUNT")

# %% [markdown]
# Evidently, we have more products that are at a price less than 200 & around 10-15 products wiht price near 1000.

# %% [markdown]
# Let us count the number of males & females.

# %%
sns.set(style="darkgrid")       #style the plot background to become a grid
genderCount  = sns.countplot(x="Gender", data = df,hue_order='gender',saturation=0.5,palette="Set2").set_title("Gender_Count")
print(list(df["Gender"].value_counts()))
# Out:
# [501, 499]

# %% [markdown]
# An almost comparable number for both

# %% [markdown]
# Let us now look at the Ratings for each branch again, this time more specifically through visualization of a boxplot.

# %%
d=sns.boxplot(x="Branch", y = "Rating" ,palette="terrain",order=["A","B","C"],data = df).set_title("Ratings by Branch")

# %% [markdown]
# Branch B has the lowest rating among all the branches
#
#
# Let's create a Line plot to visualize the time at which the most sales happen on a hourly basis.

# %%
genderCount  = sns.lineplot(x="Hours",  y = 'Quantity',color="midnightblue",data = df).set_title("Product Sales per Hour")

# %% [markdown]
# Sales by the hour at the store. Most items were sold around 14:00 hrs local time

# %% [markdown]
# Below we can see how each branch's sales quantity looks like by the hour in a monthly fashion

# %%
gender=sns.relplot(x="Hours",  y = 'Quantity', row_order=["A","B","C"],
                           col= 'Month' , row= 'Branch', kind="line",size_order=20,hue="Gender",
                           style="Gender",markers=True,linewidth=None,palette='seismic_r', data = df)
s=gender.fig.suptitle("Product Sales Per Hour On a Monthly Basis\n For Each Month")

# %% [markdown]
# Let us understand & interpret these graphs. These are the hourly sales of the quantities sold at mentioned hours. Each column represents the month. Each row represents the Branch of the company. The X-axis represents the hours at which products are sold at Y-axis Quantity.
#
# To extract information, we observe

# %% [markdown]
# Below we can see each branch's sales by the hour in a monthly fashion

# %%
genderCount  = sns.relplot(x="Hours",  y = 'Total', col= 'Month' , row= 'Branch',  row_order=["A","B","C"]
                           ,estimator = None,kind="line",markers=True ,linewidth=True,color="darkcyan",
                           size=20,data = df)

# %% [markdown]
# Let us look at the ratings for the products that were givena according to the hours. We look at this by plotting a scatter plot.

# %%
df['Rating'].unique()
Rating_count=sns.relplot(x="Rating",y="Hours",kind='scatter',data=df)

# %% [markdown]
# Evidently, ratings were given the most during 13:00 hours and 10:00 hours.
#
# The highest ratings were given again, during 10:00 hours and 16:00 hours as well, since they have the most points.
#
# During 19:00 hours, we observe the least ratings given. We can infer that time may also play a role in the given ratings for the products. Sadly, this is not something we can control, but can only observe & note down.

# %% [markdown]
# Let us look at the rating categories VS the total prices.

# %%
ageDisSpend = sns.catplot(x="Total", y = "Rating Category", data = df)

# %% [markdown]
# We observe that the ratings for a higher price product, are either Very Low or in the High category. Ratings for all product price are evenly distributed, whereas medium rating category is observed only in the low price ranges. This goes for High Rating as well.

# %% [markdown]
# # Module 5
#
# <h1>Product Analysis</h1>
#
#
# Let's look at the various products' performance.

# %%
sns.boxplot(y = 'Product line', x = 'Quantity',palette="gist_heat_r", data=df)

# %% [markdown]
# From the above visual, Health and Beauty,Electronic accessories, Sports and travel have a better average quantity sales that home & lifestyle as well as Food & beverages.

# %%
plot=sns.countplot(y = 'Product line', data=df, palette="CMRmap",order = df['Product line'].value_counts().index )

# %% [markdown]
# From the above image shows the top product line item type sold in the given dataset. Fashion Accessories is the highest while Health and beauty is the lowest. Maybe the company should focus more on selling Fashion Accessories.
#
# Let us look at the total product count that are sold based on the different product lines

# %%
plot=sns.boxplot(y = 'Product line', x = 'Total',palette="ocean_r",data=df )

# %% [markdown]
# Here, we observe that Home & Lifestyle has the most number of products that are sold, on an average. Sports & Travel, Food & Beverages, & Fashion Accessories have certain outliers as well.
#
# Now let us observe the total products that are sold on the basis of Gender & let's observe that which product line is sold more among which gender.

# %%
strip=sns.stripplot(y = 'Product line', x = 'Total', hue = 'Gender',palette= "Set1", data=df )

# %% [markdown]
# Evidently, Females are more prone to buy Fashion Accessories. Also there is  small amount of people who bought products above 1000, all females & 1 male.
#
# Home & lifestyle have an even distribution among the genders.
#
# More males brought products in the Sports & Travel category.

# %%
rel=sns.relplot(y = 'Product line', x = 'Gross Income', color="c",data=df )

# %%
box_plot=sns.boxplot(y = 'Product line', x = 'Rating',hue='Gender',palette="inferno", data=df )

# %% [markdown]
# Food and Beverages have the highest average rating while sports and travel the lowest
#
# Let's see when customers buy certain products in the various branches.

# %%
productCount  = sns.relplot(x="Hours",  y = 'Quantity', col= 'Product line' , row= 'Branch',
                            row_order=["A","B","C"],estimator = None, kind="line", data =df)

# %% [markdown]
# From the above plots, we can see that food and beverages sales usually high in all three branches at evening especially around 19:00

# %% [markdown]
# <H1>Payment Channel</h1>
# Let see how customers make payment in this business

# %%
cust= sns.countplot(x="Payment",hue="Gender", palette="plasma",data =df).set_title("Payment Channel")

# %% [markdown]
# Most of the customers pay through the Ewallet and Cash Payment while under 40 percent of them pay with their credit card. We would also like to see this payment type distribution across all the branches

# %%
Branch=sns.countplot(x="Payment", hue = "Branch", palette="Dark2",data = df).set_title("Payment Channel by Branch")

# %% [markdown]
# # Module 6
#
# <H1>Customer Analysis</H1>
# From inspection, there are two types of customers. Members and Normal. Let's see how many they are and where they are

# %%
 cust_count=sns.countplot(x="Customer Type",palette="Purples", data= df).set_title("Customer Type")

# %%
cust_type=sns.countplot(x="Customer Type", hue = "Branch",palette="PuBuGn", data =df).set_title("Customer Type by Branch")

# %% [markdown]
# Do the customer type influence customer rating? Let's find out

# %%
 type=sns.swarmplot(x="Customer Type",  y = "Rating",palette="prism",  hue = "City", data =df).set_title("Customer Type")

# %%
swarm=sns.catplot(x="Total", y="Product line", kind="swarm",palette="magma", data=df)

# %%
d=sns.countplot(x="Price Category",hue="Rating Category",palette="winter",data=df)

# %%
quantity=sns.relplot(x="Total",  y = "Quantity", color="darkcyan",data =df)

# %% [markdown]
# # Machine Learning

# %%
df["Branch"].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
df["City"].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
df["Payment"].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
df["Product line"].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
df["Customer Type"].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer Type, dtype: int64

# %%
cleanup_nums = {"Branch":     {"A": 1, "B": 2, "C": 3 },
                "City": {"Yangon": 1, "Mandalay": 2, "Naypyitaw": 3},
                "Payment": {"Ewallet": 1, "Cash": 2, "Credit card": 3},
                "Gender": {"Female": 1,"Male": 2},
                "Product line": {"Fashion accessories": 1,"Food and beverages": 2,
                                 "Electronic accessories": 3,"Sports and travel": 4,
                                 "Home and lifestyle": 5,"Health and beauty": 6}}

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %%
#CHECKING UNIQUE VALUES
print("Unique values in Branch: {0}".format(len(df['Branch'].unique().tolist())))
print("Unique values in City: {0}".format(len(df['City'].unique().tolist())))
print("Unique values in Customer Type: {0}".format(len(df['Customer Type'].unique().tolist())))
print("Unique values in Gender: {0}".format(len(df['Gender'].unique().tolist())))
print("Unique values in Product Line: {0}".format(len(df['Product line'].unique().tolist())))
print("Unique values in Payment: {0}".format(len(df['Payment'].unique().tolist())))
# Out:
# Unique values in Branch: 3
# Unique values in City: 3
# Unique values in Customer Type: 2
# Unique values in Gender: 2
# Unique values in Product Line: 6
# Unique values in Payment: 3

# %%
cleanup_nums = {"Branch":     {"A": 1, "B": 2, "C": 3 },
                "City": {"Yangon": 1, "Mandalay": 2, "Naypyitaw": 3},
                "Payment": {"Ewallet": 1, "Cash": 2, "Credit card": 3},
                "Gender": {"Female": 1,"Male": 2},
                "Product line": {"Fashion accessories": 1,"Food and beverages": 2,"Electronic accessories": 3,
                                 "Sports and travel": 4,"Home and lifestyle": 5,"Health and beauty": 6},
                "Customer Type": {"Member": 1,"Normal": 2}}

# %%
df.replace(cleanup_nums, inplace=True)
df.head()
df.shape
# Out:
# (1000, 24)

# %%
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
test = df[~msk]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['Branch','City','Customer Type','Gender','Product line','Quantity','Payment']])
y = np.asanyarray(train[['Total']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [[-1.91646806e+15  1.91646806e+15 -8.63281250e+00  7.10937500e+00
#   -4.64062500e+00  5.83906250e+01  5.25000000e+00]]

# %%
y_hat= regr.predict(test[['Branch','City','Customer Type','Gender','Product line','Quantity','Payment']])
x = np.asanyarray(test[['Branch','City','Customer Type','Gender','Product line','Quantity','Payment']])
y = np.asanyarray(test[['Total']])
print("Residual sum of squares: %.2f"
      % np.mean((y_hat - y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Residual sum of squares: 31542.93
# Variance score: 0.52

# %%
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['Branch','City','Customer Type','Gender','Product line','Unit price','Quantity','Payment']])
y = np.asanyarray(train[['Total']])
regr.fit (x, y)
print ('Coefficients: ', regr.coef_)
y_= regr.predict(test[['Branch','City','Customer Type','Gender','Product line','Unit price','Quantity','Payment']])
x = np.asanyarray(test[['Branch','City','Customer Type','Gender','Product line','Unit price','Quantity','Payment']])
y = np.asanyarray(test[['Total']])
print("Residual sum of squares: %.2f"% np.mean((y_ - y) ** 2))
print('Prediction Percentage: %.2f' % regr.score(x, y))
# Out:
# Coefficients:  [[ 2.06297665  2.06297665  1.50504654  0.7134891   1.23893333  5.79167638
#   58.54450203  6.58534905]]
# Residual sum of squares: 6725.06
# Prediction Percentage: 0.90
